# %%
import pandas as pd
df = pd.read_csv('df.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            5250 non-null   int64
#  1   Country Name    5250 non-null   object
#  2   Indicator Name  5250 non-null   object
#  3   Value           5250 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 164.2+ KB

# %%
df['Value'] = df['Value'].round(2)

# %%
from dash import Dash, html, dcc, Input, Output
import pandas as pd
import plotly.express as px
import dash_bootstrap_components as dbc
import warnings
warnings.filterwarnings('ignore')

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
# add bootstrap LUX theme
app = Dash(__name__, external_stylesheets=[dbc.themes.LUX])
app.title = 'Page 2'

app.layout = html.Div([
    html.Div([

    html.H2('Analysis between Different Indicators', style={'textAlign': 'center'}),

        html.Div([
            dcc.Dropdown(   
                df['Indicator Name'].unique(),
                'Fertility rate, total (births per woman)',
                id='crossfilter-xaxis-column',
            ),
            dcc.RadioItems(
                ['Linear', 'Log'],
                'Linear',
                id='crossfilter-xaxis-type',
                labelStyle={'display': 'inline-block', 'marginTop': '5px'}
            )
        ],
        style={'width': '49%', 'display': 'inline-block'}),

        html.Div([
            dcc.Dropdown(
                df['Indicator Name'].unique(),
                'Life expectancy at birth, total (years)',
                id='crossfilter-yaxis-column'
            ),
            dcc.RadioItems(
                ['Linear', 'Log'],
                'Linear',
                id='crossfilter-yaxis-type',
                labelStyle={'display': 'inline-block', 'marginTop': '5px'}
            )
        ], style={'width': '49%', 'float': 'right', 'display': 'inline-block'})
    ], style={
        'padding': '10px 5px'
    }),

    html.Div([
        dcc.Graph(
            id='crossfilter-indicator-scatter',
            hoverData={'points': [{'customdata': 'Japan'}]}
        )
    ], style={'width': '49%', 'display': 'inline-block', 'padding': '0 20'}),
    html.Div([
        dcc.Graph(id='x-time-series'),
        dcc.Graph(id='y-time-series'),
    ], style={'display': 'inline-block', 'width': '49%'}),

    html.Div(dcc.Slider(
        df['Year'].min(),
        df['Year'].max(),
        step=None,
        id='crossfilter-year--slider',
        value=df['Year'].max(),
        marks={str(year): str(year) for year in df['Year'].unique()}
    ), style={'width': '49%', 'padding': '0px 20px 20px 20px'})
])


@app.callback(
    Output('crossfilter-indicator-scatter', 'figure'),
    Input('crossfilter-xaxis-column', 'value'),
    Input('crossfilter-yaxis-column', 'value'),
    Input('crossfilter-xaxis-type', 'value'),
    Input('crossfilter-yaxis-type', 'value'),
    Input('crossfilter-year--slider', 'value'))

def update_graph(xaxis_column_name, yaxis_column_name,
                 xaxis_type, yaxis_type,
                 year_value):
    dff = df[df['Year'] == year_value]

    fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
                     y=dff[dff['Indicator Name'] == yaxis_column_name]['Value'],
                     hover_name=dff[dff['Indicator Name'] == yaxis_column_name]['Country Name'],
                     text=dff[dff['Indicator Name'] == yaxis_column_name]['Country Name'],
                     size_max=60,
                     color=dff[dff['Indicator Name'] == yaxis_column_name]['Value'],
                     color_continuous_scale='Viridis')  # Specify the color scale here

    fig.update_traces(customdata=dff[dff['Indicator Name'] == yaxis_column_name]['Country Name'],
                      textposition='top center')

    fig.update_xaxes(title=xaxis_column_name, type='linear' if xaxis_type == 'Linear' else 'log')

    fig.update_yaxes(title=yaxis_column_name, type='linear' if yaxis_type == 'Linear' else 'log')

    fig.update_layout(margin={'l': 40, 'b': 40, 't': 10, 'r': 0}, hovermode='closest', height=430, template='simple_white')

    return fig



def create_time_series(dff, axis_type, title):
    fig = px.scatter(dff, x='Year', y='Value')
    fig.update_traces(mode='lines+markers+text')
    fig.update_xaxes(showgrid=False)
    fig.update_yaxes(type='linear' if axis_type == 'Linear' else 'log')

    # Add annotations
    annotations = []
    for i, row in dff.iterrows():
        annotation = dict(
            x=row['Year'],
            y=row['Value'],
            text=row['Value'],
            showarrow=False,
            font=dict(size=10, color='black'),
            xanchor='center',
            yanchor='bottom'
        )
        annotations.append(annotation)

    fig.update_layout(
        margin={'l': 40, 'b': 40, 't': 10, 'r': 0},
        height=430,
        template='simple_white',
        annotations=annotations
    )

    return fig


@app.callback(
    Output('x-time-series', 'figure'),
    Input('crossfilter-indicator-scatter', 'hoverData'),
    Input('crossfilter-xaxis-column', 'value'),
    Input('crossfilter-xaxis-type', 'value'))
def update_y_timeseries(hoverData, xaxis_column_name, axis_type):
    country_name = hoverData['points'][0]['customdata']
    dff = df[df['Country Name'] == country_name]
    dff = dff[dff['Indicator Name'] == xaxis_column_name]
    title = '<b>{}</b><br>{}'.format(country_name, xaxis_column_name)
    return create_time_series(dff, axis_type, title)


@app.callback(
    Output('y-time-series', 'figure'),
    Input('crossfilter-indicator-scatter', 'hoverData'),
    Input('crossfilter-yaxis-column', 'value'),
    Input('crossfilter-yaxis-type', 'value'))
def update_x_timeseries(hoverData, yaxis_column_name, axis_type):
    dff = df[df['Country Name'] == hoverData['points'][0]['customdata']]
    dff = dff[dff['Indicator Name'] == yaxis_column_name]
    return create_time_series(dff, axis_type, yaxis_column_name)


if __name__ == '__main__':
    app.run_server(port=8888)
# Out:
# Dash is running on http://127.0.0.1:8888/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8888
# Press CTRL+C to quit
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# [2023-06-01 11:48:42,474] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1328, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 11:48:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:43] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 11:48:45,628] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 11:48:45] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 11:48:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 11:48:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:46] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:07:48,679] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:07:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:48] "POST /_dash-update-component HTTP/1.1" 500 -
# [2023-06-01 12:07:51,565] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:07:51] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:07:51] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:07:55,898] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:07:55] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:07:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:07:57] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:07:59,770] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1328, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# 127.0.0.1 - - [01/Jun/2023 12:07:59] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:07:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# [2023-06-01 12:08:01,866] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1328, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 12:08:01] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 12:08:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:02] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:08:03,766] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:08:03] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:08:03] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:08:07,721] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:08:07] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:08:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# [2023-06-01 12:08:12,617] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1328, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:12] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:08:14,012] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:08:14] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:08:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:16] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:08:18,591] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:08:18] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:08:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:08:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:10:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:10:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:10:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:10:59] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:12:54,087] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:12:54] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:12:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:12:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 12:12:56] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:13:01,085] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1996, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1409, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/plotly/express/_core.py", line 1246, in process_args_into_dataframe
#     raise ValueError(
# ValueError: All arguments should have the same length. The length of argument `hover_name` is 0, whereas the length of  previously-processed arguments ['x'] is 26
# 127.0.0.1 - - [01/Jun/2023 12:13:01] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Jun/2023 12:13:01] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-01 12:13:02,211] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/27/mp6sy3_d6_lgz19hyp_8n8z40000gn/T/ipykernel_32702/3131496709.py", line 85, in update_graph
#     fig = px.scatter(x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
# 127.0.0.1 - - [01/Jun/2023 13:09:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:09:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:09:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:09:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:09:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:10:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:11:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:11:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:11:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:11:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:12:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:45:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:45:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:45:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:45:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:46:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:47:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:47:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:47:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:47:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:47:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:47:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:52:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:54:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:54:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:54:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:54:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:54:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 13:54:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:24:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:25:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:25:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:25:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:25:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:25:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:25:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:25:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:25:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:26:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:26:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:26:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:26:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:58:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:58:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:59:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:59:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:59:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 14:59:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:00:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:01:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:01:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:01:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:01:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:01:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:01:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:01:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:01:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:02:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:03:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2023 15:03:01] "POST /_dash-update-component HTTP/1.1" 200 -
